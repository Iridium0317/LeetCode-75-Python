# %% [markdown]
# # 443. String Compression
#
# **题目链接**: [LeetCode Link](这里换成链接)
#
# ## Problem Description
#
# (在此处直接粘贴题目截图 📸)

# %%
class Solution:
    def functionName(self, args):
        pass

# %% [markdown]
# ## Complexity Analysis
#
# - **Time Complexity**: $O(n)$
#   - *Reasoning*: ...
# - **Space Complexity**: $O(1)$
#   - *Reasoning*: ...

# %% [markdown]
# ## Takeaways / Notes
#
# - [ ] Key Point 1 (e.g., Use two pointers to optimize O(n^2) to O(n))
# - [ ] Key Point 2 (e.g., Python strings are immutable, use list for collection)
# - [ ] Pitfall to avoid...
