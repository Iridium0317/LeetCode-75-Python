# %% [markdown]
# # 724. Find Pivot Index
#
# **题目链接**: [LeetCode Link](https://leetcode.cn/problems/find-pivot-index/description/?envType=study-plan-v2&envId=leetcode-75)
#
# ## Problem Description
#
# ![image.png](attachment:image.png)

# %%
class Solution:
    def pivotIndex(self, nums: List[int]) -> int:
        total_sum = sum(nums)
        
        left_sum = 0
        
        for i, num in enumerate(nums):
  
            if left_sum == (total_sum - left_sum - num):
                return i
            
            left_sum += num
        return -1

# %% [markdown]
# ## Complexity Analysis
#
# - **Time Complexity**: $O(n)$
#   - *Reasoning*: ...
# - **Space Complexity**: $O(1)$
#   - *Reasoning*: 只需要 total_sum 和 current_left 两个变量

# %%
class Solution:
    def pivotIndex(self, nums: List[int]) -> int:
        n = len(nums)
        left_sum = [0] * n
        right_sum = [0] * n
        
        for i in range(1, n):
            left_sum[i] = left_sum[i-1] + nums[i-1]
            
        for i in range(n-2, -1, -1):
            right_sum[i] = right_sum[i+1] + nums[i+1]
        # 倒序遍历 
           
        # 对比两个数组，找到第一个相等的位置
        for i in range(n):
            if left_sum[i] == right_sum[i]:
                return i
                
        return -1

# %% [markdown]
# ## Complexity Analysis
#
# - **Time Complexity**: $O(n)$
#   - *Reasoning*: ...
# - **Space Complexity**: $O(n)$
#   - *Reasoning*: O(N)+O(N)+O(N)=O(3N)

# %% [markdown]
# ## Takeaways / Notes
#
# - [ ] Right Sum = Total Sum - Left Sum - nums[i]
# - [ ] Right Sum == Left Sum
# - [ ] Left Sum = Total Sum - Left Sum - nums[i]
